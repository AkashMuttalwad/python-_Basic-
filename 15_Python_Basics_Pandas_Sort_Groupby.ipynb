# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashMuttalwad/python-_Basic-/blob/main/15_Python_Basics_Pandas_Sort_Groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Dataframe.sort_values()**
# Pandas sort_values() function sorts a data frame in Ascending or Descending order of passed Column. It’s different than the sorted Python function since it cannot sort a data frame and particular column cannot be selected.

# %%
import pandas as pd
import numpy as np

# %%
#reading csv files 
data =  pd.read_csv("/content/drive/MyDrive/Copy of nba.csv")

# %%
#Getting data 
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.sort_values("Name", axis = 0, ascending = True, na_position ='last')
#shorting data by name and Na Postions at last Calling
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
#sorting data frame by Team and then By names
data.sort_values(["Team", "Name"], axis=0,
                 ascending=True)
# Out:
#                 Name                Team  Number Position   Age Height  \
# 312       Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 323      Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 311     Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# ..               ...                 ...     ...      ...   ...    ...
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 457              NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight       College      Salary
# 312   245.0       Florida  12000000.0
# ...

# %% [markdown]
# # **Group By** important in Python
# Groupby is a pretty simple concept. We can create a grouping of categories and apply a function to the categories. It’s a simple concept but it’s an extremely valuable technique that’s widely used in data science. In real data science projects, you’ll be dealing with large amounts of data and trying things over and over, so for efficiency, we use Groupby concept. Groupby concept is really important because it’s ability to aggregate data efficiently, both in performance and the amount code is magnificent. Groupby mainly refers to a process involving one or more of the following steps they are:
#
# Splitting : It is a process in which we split data into group by applying some conditions on datasets. Applying : It is a process in which we apply a function to each group independently Combining : It is a process in which we combine different datasets after applying groupby and results into a data structure The following image will help in understanding a process involve in Groupby concept.
#
# Group the unique values from the Team column

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now there’s a bucket for each group
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Toss the other data into the buckets
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Apply a function on the weight column of each bucket.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Splitting Data into Groups**
# Splitting is a process in which we split data into a group by applying some conditions on datasets. In order to split the data, we apply certain conditions on datasets. In order to split the data, we use groupby() function this function is used to split the data into groups based on some criteria. Pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names. Pandas datasets can be split into any of their objects. There are multiple ways to split data like:
#
# obj.groupby(key)
#
# obj.groupby(key, axis=1)
#
# obj.groupby([key1, key2])
#
# Note :In this we refer to the grouping objects as the keys.
#
# Grouping data with one key: In order to group data with one key, we pass only one key as an argument in groupby function.

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing Plyers data
data1 = {'Name':['viru', 'sachin', 'dhoni', 'dravid',
				'ganguly', 'yuvi', 'dhawan', 'kohali'],
		'runs':[2447, 2774, 8887, 8732,
			3300, 3996, 2877, 7632],
		'stadium':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'award':['most runs', 'man of the match', 'man of the series', 'Phbest filder',
						'best captian', 'best keeper ', 'best bowler', 'best finhisher']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#       Name  runs    stadium              award
# 0     viru  2447     Nagpur          most runs
# 1   sachin  2774     Kanpur   man of the match
# 2    dhoni  8887  Allahabad  man of the series
# 3   dravid  8732    Kannuaj      Phbest filder
# 4  ganguly  3300    Jaunpur       best captian
# 5     yuvi  3996     Kanpur       best keeper
# 6   dhawan  2877  Allahabad        best bowler
# 7   kohali  7632    Aligarh     best finhisher

# %%
# Now we group a data of Name using groupby() function. 
# using groupby function
# with one key

df.groupby('Name')
print(df.groupby('Name').groups)
# Out:
# {'dhawan': [6], 'dhoni': [2], 'dravid': [3], 'ganguly': [4], 'kohali': [7], 'sachin': [1], 'viru': [0], 'yuvi': [5]}

# %%
# Now we print the first entries in all the groups formed. 
# applying groupby() function to
# group the data on Name value.
gk = df.groupby('Name')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#          runs    stadium              award
# Name
# dhawan   2877  Allahabad        best bowler
# dhoni    8887  Allahabad  man of the series
# dravid   8732    Kannuaj      Phbest filder
# ganguly  3300    Jaunpur       best captian
# kohali   7632    Aligarh     best finhisher
# sachin   2774     Kanpur   man of the match
# viru     2447     Nagpur          most runs
# yuvi     3996     Kanpur       best keeper

# %% [markdown]
# # **Grouping data with multiple keys :**

# %%
import pandas as pd

# Define a dictionary containing Plyers data
data1 = {'Name':['viru', 'sachin', 'dhoni', 'dravid',
				'ganguly', 'yuvi', 'dhawan', 'kohali'],
		'runs':[2447, 2774, 8887, 8732,
			3300, 3996, 2877, 7632],
		'stadium':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'award':['most runs', 'man of the match', 'man of the series', 'Phbest filder',
						'best captian', 'best keeper ', 'best bowler', 'best finhisher']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#       Name  runs    stadium              award
# 0     viru  2447     Nagpur          most runs
# 1   sachin  2774     Kanpur   man of the match
# 2    dhoni  8887  Allahabad  man of the series
# 3   dravid  8732    Kannuaj      Phbest filder
# 4  ganguly  3300    Jaunpur       best captian
# 5     yuvi  3996     Kanpur       best keeper
# 6   dhawan  2877  Allahabad        best bowler
# 7   kohali  7632    Aligarh     best finhisher

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['dhoni', 'viru', 'sachin', 'dhoni',
				'viru', 'dravid', 'akash', 'Abhi'],
		'Runs':[547, 765, 768, 765,
			987, 987, 543, 567],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'award':['most runs', 'man of the match', 'man of the series', 'Phbest filder',
						'best captian', 'best keeper ', 'best bowler', 'best finhisher']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Runs    Address              award
# 0   dhoni   547     Nagpur          most runs
# 1    viru   765     Kanpur   man of the match
# 2  sachin   768  Allahabad  man of the series
# 3   dhoni   765    Kannuaj      Phbest filder
# 4    viru   987    Jaunpur       best captian
# 5  dravid   987     Kanpur       best keeper
# 6   akash   543  Allahabad        best bowler
# 7    Abhi   567    Aligarh     best finhisher

# %%
# Now we group a data of “Name” and “Qualification” together using multiple keys in groupby function. 
# Using multiple keys in
# groupby() function
df.groupby(['Name', 'award'])

print(df.groupby(['Name', 'award']).groups)
# Out:
# {('Abhi', 'best finhisher'): [7], ('akash', 'best bowler'): [6], ('dhoni', 'Phbest filder'): [3], ('dhoni', 'most runs'): [0], ('dravid', 'best keeper '): [5], ('sachin', 'man of the series'): [2], ('viru', 'best captian'): [4], ('viru', 'man of the match'): [1]}

# %%
# Now we print the first entries in all the groups formed. 
# applying groupby() function to
# group the data on Name value.
gk = df.groupby('Name')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#         Runs    Address              award
# Name
# Abhi     567    Aligarh     best finhisher
# akash    543  Allahabad        best bowler
# dhoni    547     Nagpur          most runs
# dravid   987     Kanpur       best keeper
# sachin   768  Allahabad  man of the series
# viru     765     Kanpur   man of the match

# %% [markdown]
# # **Grouping data by sorting keys :**
#
# Group keys are sorted by default using the groupby operation. User can pass sort=False for potential speedups.

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32], }
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age
# 0     Jai   27
# 1    Anuj   24
# 2     Jai   22
# 3  Princi   32
# 4  Gaurav   33
# 5    Anuj   36
# 6  Princi   27
# 7    Abhi   32

# %%
# using groupby function
# without using sort




df.groupby(['Name'])["Age"].sum()#Now we apply groupby() without sort
# Out:
# Name
# Abhi      32
# Anuj      60
# Gaurav    33
# Jai       49
# Princi    59
# Name: Age, dtype: int64

# %% [markdown]
# # **Applying function to group**
# After splitting a data into a group, we apply a function to each group in order to do that we perform some operation they are:
#
# # **Aggregation :**
#
# It is a process in which we compute a summary statistic (or statistics) about each group. For Example, Compute group sums or means
# Transformation : It is a process in which we perform some group-specific computations and return a like-indexed. For Example, Filling NAs within groups with a value derived from each group
# Filtration : It is a process in which we discard some groups, according to a group-wise computation that evaluates True or False. For Example, Filtering out data based on the group sum or mean
# Aggregation :
# Aggregation is a process in which we compute a summary statistic about each group. Aggregated function returns a single aggregated value for each group. After splitting a data into groups using groupby function, several aggregation operations can be performed on the grouped data. Code #1: Using aggregation via the aggregate method.

# %%
# importing pandas module
import pandas as pd

# importing numpy as np
import numpy as np

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
# performing aggregation using
# aggregate method

grp1 = df.groupby('Name')

grp1.aggregate(np.sum)
# Out:
#         Age
# Name
# Abhi     32
# Anuj     60
# Gaurav   33
# Jai      49
# Princi   59

# %%
# performing aggregation on
# group containing multiple
# keys
grp1 = df.groupby(['Name', 'Qualification'])

grp1.aggregate(np.sum)
# Out:
#                       Age
# Name   Qualification
# Abhi   MA              32
# Anuj   B.com           36
#        MA              24
# Gaurav B.Tech          33
# Jai    MCA             22
#        Msc             27
# Princi Msc             27
#        Phd             32

# %% [markdown]
# Applying multiple functions at once :
#
# We can apply a multiple functions at once by passing a list or dictionary of functions to do aggregation with, outputting a DataFrame.

# %%
# importing pandas module
import pandas as pd

# importing numpy as np
import numpy as np

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
# applying a function by passing
# a list of functions

grp = df.groupby('Name')
grp['Age'].agg([np.sum, np.mean, np.std,np.min])
# Out:
#         sum  mean       std  amin
# Name
# Abhi     32  32.0       NaN    32
# Anuj     60  30.0  8.485281    24
# Gaurav   33  33.0       NaN    33
# Jai      49  24.5  3.535534    22
# Princi   59  29.5  3.535534    27

# %% [markdown]
# Note: Aggregations:
# count() – Number of non-null observations
#
# sum() – Sum of values
#
# mean() – Mean of values
#
# median() – Arithmetic median of values
#
# min() – Minimum
#
# max() – Maximum
#
# mode() – Mode
#
# std() – Standard deviation
#
# var() – Variance
#
# But the agg() function in Pandas gives us the flexibility to perform several statistical computations all at once! Here is how it works:

# %%
# importing pandas module
import pandas as pd

# importing numpy as np
import numpy as np

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA'],
		'Score': [23, 34, 35, 45, 47, 50, 52, 53]}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 4  Gaurav   33    Jaunpur        B.Tech     47
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52
# 7    Abhi   32    Aligarh            MA     53

# %% [markdown]
# # **Transformation :**
# Transformation is a process in which we perform some group-specific computations and return a like-indexed. Transform method returns an object that is indexed the same (same size) as the one being grouped. The transform function must:
#
# Return a result that is either the same size as the group
#
# Operate column-by-column on the group.
#
# Not perform in-place operations on the group.
#
# The transform() function is used to call function on self producing a Series with transformed values and that has the same axis length as self.

# %%
df = pd.DataFrame({'P': range(4), 'Q': range(2, 6)})
df
# Out:
#    P  Q
# 0  0  2
# 1  1  3
# 2  2  4
# 3  3  5

# %%
df.transform(lambda x: x + 2)
# Out:
#    P  Q
# 0  2  4
# 1  3  5
# 2  4  6
# 3  5  7

# %%
# calculating sqrt and exponential
df.transform([np.sqrt, np.exp])
# Out:
#           P                    Q
#        sqrt        exp      sqrt         exp
# 0  0.000000   1.000000  1.414214    7.389056
# 1  1.000000   2.718282  1.732051   20.085537
# 2  1.414214   7.389056  2.000000   54.598150
# 3  1.732051  20.085537  2.236068  148.413159
