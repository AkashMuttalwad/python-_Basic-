# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashMuttalwad/python-_Basic-/blob/main/Installation_%2CGit_%2CVS_Code_%2CNotepad%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Python program to swap two variables
print("Hello")
x = 8
y = 15
#Create a temporary variable and swap the values
temp = x
x = y
y = temp
print(x)
print(y)
